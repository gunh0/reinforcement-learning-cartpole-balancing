# %% [markdown]
# # Microsoft Student Partners(MSP) Korea
# # Reinforcement Learning

# %%
# Environment Settings
# Import modules

# import matplotlib
# import matplotlib.pyplot as plt
# %matplotlib inline

# Load OpenAI Gym
import gym
import numpy as np

import random
import math

# %%
# Load OpenAI Gym's Environment
# Environment title 'CartPole-v0'
env = gym.make('CartPole-v0')

# Modify environment to expand steps(500) at each episode
env._max_episode_steps = 500

# Defining the environment related constants
# Number of discrete states (bucket) per state dimension
NUM_BUCKETS = (1, 1, 6, 3)  # (x, x', theta, theta')

# Number of discrete actions
NUM_ACTIONS = env.action_space.n # (left, right)

# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))
STATE_BOUNDS[1] = [-0.5, 0.5]
STATE_BOUNDS[3] = [-math.radians(50), math.radians(50)]

# Index of the action
ACTION_INDEX = len(NUM_BUCKETS)

# %%
# Defining the Q-learning related constants
# import numpy as np

## Creating a Q-Table for each state-action pair
q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,))

## Defining the Learning related constants
MIN_EXPLORE_RATE = 0.01
MIN_LEARNING_RATE = 0.1
DISCOUNT_FACTOR = 0.99

## Defining the simulation related constants
MAX_EPISODES = 1000     # 몇 번이나 기회를 줄까?
MAX_STEPS = 550         # 이정도면 잘 버텼다!
SOLVED_STEPS = 499      # 이정도면 잘 버텼다!
STREAK_TO_END = 120

# %%
record = []


# Implement Sub-modules
# Get learning related values at the given time t
""" import math """
# Decreasing exploring rate over time t
def get_explore_rate(t):
    # if t >= 24:
    if t >= 5:
        # Does not decreas below the MIN_EXPLORE_RATE
        return max(MIN_EXPLORE_RATE, min(1, 1.0 - math.log10((t+1)/25)))
    else:
        return 1.0

# Decreasing learning rate over time t
def get_learning_rate(t):
    # if t >= 24:
    if t >= 5:
        # Does not decreas below the MIN_LEARNING_RATE
         return max(MIN_LEARNING_RATE, min(0.5, 1.0 - math.log10((t+1)/25)))
    else:
         return 1.0

# Get the most proper action at the given state
# import numpy as np
# import random
def select_action(state, explore_rate):
    """ Code Start """

    # Select a random action : Epsilon-greedy
    if random.random() < explore_rate:
        action = env.action_space.sample()

    # Select the action with the highest q
    else:
        action = np.argmax(q_table[state])

    """ Code End """
    return action

# Convert observation to state
def observation_to_state(observation):
    state = []
    for i in range(len(observation)):
        if observation[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif observation[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*observation[i] - offset))
        state.append(bucket_index)
    return tuple(state)


# Simulate Q-Learning
def simulate():
    num_streaks = 0

    for episode in range(MAX_EPISODES):
        """ Code Start """

        # Initiate learning related values
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)

        """ Code End """

        # Reset the environment
        obv = env.reset()
        state_prev = observation_to_state(obv)

        for step in range(MAX_STEPS):
            """ Code Start """

            # Select an action
            action = select_action(state_prev, explore_rate)

            # Execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state_next = observation_to_state(obv)

            # Update the Q based on the result
            best_q = np.amax(q_table[state_next])
            q_table[state_prev + (action,)] += learning_rate * (reward + DISCOUNT_FACTOR * best_q - q_table[state_prev + (action,)])

            """ Code End """
            # Setting up for the next iteration
            state_prev = state_next

            if done:
                record.append(step)
                print("Episode %d finished after %f time steps" % (episode, step))
                if (step >= SOLVED_STEPS):
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

        # It's considered done when it's solved over STREAK_TO_END times consecutively
        if num_streaks > STREAK_TO_END:
            break

# %%
# Visualize time-reward Graph
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline    # 주피터 노트북 상에서 그래프를 표현하기 위한 라인

def visualize():
    plt.figure(figsize=(20,8))
    plt.plot(range(len(record)), record)
    plt.show()

if __name__ == "__main__":
    simulate()
# Out:
# Episode 0 finished after 9.000000 time steps
# Episode 1 finished after 14.000000 time steps
# Episode 2 finished after 48.000000 time steps
# Episode 3 finished after 33.000000 time steps
# Episode 4 finished after 9.000000 time steps
# Episode 5 finished after 16.000000 time steps
# Episode 6 finished after 36.000000 time steps
# Episode 7 finished after 32.000000 time steps
# Episode 8 finished after 20.000000 time steps
# Episode 9 finished after 15.000000 time steps
# Episode 10 finished after 14.000000 time steps
# Episode 11 finished after 20.000000 time steps
# Episode 12 finished after 23.000000 time steps
# Episode 13 finished after 11.000000 time steps
# Episode 14 finished after 16.000000 time steps
# Episode 15 finished after 10.000000 time steps
# Episode 16 finished after 9.000000 time steps
# Episode 17 finished after 30.000000 time steps
# Episode 18 finished after 14.000000 time steps
# Episode 19 finished after 18.000000 time steps
# Episode 20 finished after 34.000000 time steps
# Episode 21 finished after 30.000000 time steps
# Episode 22 finished after 16.000000 time steps
# Episode 23 finished after 27.000000 time steps
# Episode 24 finished after 29.000000 time steps
# Episode 25 finished after 11.000000 time steps
# Episode 26 finished after 33.000000 time steps
# Episode 27 finished after 27.000000 time steps
# Episode 28 finished after 41.000000 time steps
# Episode 29 finished after 25.000000 time steps
# Episode 30 finished after 13.000000 time steps
# Episode 31 finished after 10.000000 time steps
# Episode 32 finished after 19.000000 time steps
# Episode 33 finished after 46.000000 time steps
# Episode 34 finished after 10.000000 time steps
# Episode 35 finished after 11.000000 time steps
# Episode 36 finished after 12.000000 time steps
# Episode 37 finished after 21.000000 time steps
# Episode 38 finished after 23.000000 time steps
# Episode 39 finished after 19.000000 time steps
# Episode 40 finished after 10.000000 time steps
# Episode 41 finished after 12.000000 time steps
# Episode 42 finished after 14.000000 time steps
# Episode 43 finished after 10.000000 time steps
# Episode 44 finished after 16.000000 time steps
# Episode 45 finished after 11.000000 time steps
# Episode 46 finished after 33.000000 time steps
# Episode 47 finished after 33.000000 time steps
# Episode 48 finished after 44.000000 time steps
# Episode 49 finished after 17.000000 time steps
# Episode 50 finished after 15.000000 time steps
# Episode 51 finished after 17.000000 time steps
# Episode 52 finished after 21.000000 time steps
# Episode 53 finished after 25.000000 time steps
# Episode 54 finished after 59.000000 time steps
# Episode 55 finished after 17.000000 time steps
# Episode 56 finished after 99.000000 time steps
# Episode 57 finished after 26.000000 time steps
# Episode 58 finished after 10.000000 time steps
# Episode 59 finished after 19.000000 time steps
# Episode 60 finished after 11.000000 time steps
# Episode 61 finished after 11.000000 time steps
# Episode 62 finished after 90.000000 time steps
# Episode 63 finished after 22.000000 time steps
# Episode 64 finished after 29.000000 time steps
# Episode 65 finished after 24.000000 time steps
# Episode 66 finished after 12.000000 time steps
# Episode 67 finished after 13.000000 time steps
# Episode 68 finished after 13.000000 time steps
# Episode 69 finished after 16.000000 time steps
# Episode 70 finished after 25.000000 time steps
# Episode 71 finished after 16.000000 time steps
# Episode 72 finished after 137.000000 time steps
# Episode 73 finished after 32.000000 time steps
# Episode 74 finished after 40.000000 time steps
# Episode 75 finished after 24.000000 time steps
# Episode 76 finished after 32.000000 time steps
# Episode 77 finished after 83.000000 time steps
# Episode 78 finished after 33.000000 time steps
# Episode 79 finished after 29.000000 time steps
# Episode 80 finished after 27.000000 time steps
# Episode 81 finished after 71.000000 time steps
# Episode 82 finished after 163.000000 time steps
# Episode 83 finished after 13.000000 time steps
# Episode 84 finished after 10.000000 time steps
# Episode 85 finished after 27.000000 time steps
# Episode 86 finished after 32.000000 time steps
# Episode 87 finished after 15.000000 time steps
# Episode 88 finished after 34.000000 time steps
# Episode 89 finished after 10.000000 time steps
# Episode 90 finished after 63.000000 time steps
# Episode 91 finished after 49.000000 time steps
# Episode 92 finished after 10.000000 time steps
# Episode 93 finished after 14.000000 time steps
# Episode 94 finished after 9.000000 time steps
# Episode 95 finished after 10.000000 time steps
# Episode 96 finished after 10.000000 time steps
# Episode 97 finished after 33.000000 time steps
# Episode 98 finished after 8.000000 time steps
# Episode 99 finished after 38.000000 time steps
# Episode 100 finished after 11.000000 time steps
# Episode 101 finished after 16.000000 time steps
# Episode 102 finished after 12.000000 time steps
# Episode 103 finished after 136.000000 time steps
# Episode 104 finished after 35.000000 time steps
# Episode 105 finished after 27.000000 time steps
# Episode 106 finished after 24.000000 time steps
# Episode 107 finished after 12.000000 time steps
# Episode 108 finished after 18.000000 time steps
# Episode 109 finished after 10.000000 time steps
# Episode 110 finished after 18.000000 time steps
# Episode 111 finished after 14.000000 time steps
# Episode 112 finished after 89.000000 time steps
# Episode 113 finished after 27.000000 time steps
# Episode 114 finished after 81.000000 time steps
# Episode 115 finished after 9.000000 time steps
# Episode 116 finished after 83.000000 time steps
# Episode 117 finished after 10.000000 time steps
# Episode 118 finished after 104.000000 time steps
# Episode 119 finished after 13.000000 time steps
# Episode 120 finished after 15.000000 time steps
# Episode 121 finished after 9.000000 time steps
# Episode 122 finished after 382.000000 time steps
# Episode 123 finished after 153.000000 time steps
# Episode 124 finished after 10.000000 time steps
# Episode 125 finished after 245.000000 time steps
# Episode 126 finished after 15.000000 time steps
# Episode 127 finished after 36.000000 time steps
# Episode 128 finished after 10.000000 time steps
# Episode 129 finished after 384.000000 time steps
# Episode 130 finished after 220.000000 time steps
# Episode 131 finished after 9.000000 time steps
# Episode 132 finished after 96.000000 time steps
# Episode 133 finished after 17.000000 time steps
# Episode 134 finished after 122.000000 time steps
# Episode 135 finished after 21.000000 time steps
# Episode 136 finished after 18.000000 time steps
# Episode 137 finished after 7.000000 time steps
# Episode 138 finished after 77.000000 time steps
# Episode 139 finished after 17.000000 time steps
# Episode 140 finished after 499.000000 time steps
# Episode 141 finished after 309.000000 time steps
# Episode 142 finished after 82.000000 time steps
# Episode 143 finished after 27.000000 time steps
# Episode 144 finished after 72.000000 time steps
# Episode 145 finished after 227.000000 time steps
# Episode 146 finished after 31.000000 time steps
# Episode 147 finished after 111.000000 time steps
# Episode 148 finished after 20.000000 time steps
# Episode 149 finished after 383.000000 time steps
# Episode 150 finished after 380.000000 time steps
# Episode 151 finished after 168.000000 time steps
# Episode 152 finished after 20.000000 time steps
# Episode 153 finished after 104.000000 time steps
# Episode 154 finished after 25.000000 time steps
# Episode 155 finished after 319.000000 time steps
# Episode 156 finished after 346.000000 time steps
# Episode 157 finished after 499.000000 time steps
# Episode 158 finished after 367.000000 time steps
# Episode 159 finished after 499.000000 time steps
# Episode 160 finished after 499.000000 time steps
# Episode 161 finished after 499.000000 time steps
# Episode 162 finished after 499.000000 time steps
# Episode 163 finished after 195.000000 time steps
# Episode 164 finished after 19.000000 time steps
# Episode 165 finished after 23.000000 time steps
# Episode 166 finished after 14.000000 time steps
# Episode 167 finished after 499.000000 time steps
# Episode 168 finished after 456.000000 time steps
# Episode 169 finished after 415.000000 time steps
# Episode 170 finished after 39.000000 time steps
# Episode 171 finished after 26.000000 time steps
# Episode 172 finished after 137.000000 time steps
# Episode 173 finished after 22.000000 time steps
# Episode 174 finished after 9.000000 time steps
# Episode 175 finished after 18.000000 time steps
# Episode 176 finished after 12.000000 time steps
# Episode 177 finished after 36.000000 time steps
# Episode 178 finished after 23.000000 time steps
# Episode 179 finished after 58.000000 time steps
# Episode 180 finished after 22.000000 time steps
# Episode 181 finished after 370.000000 time steps
# Episode 182 finished after 499.000000 time steps
# Episode 183 finished after 499.000000 time steps
# Episode 184 finished after 499.000000 time steps
# Episode 185 finished after 499.000000 time steps
# Episode 186 finished after 499.000000 time steps
# Episode 187 finished after 499.000000 time steps
# Episode 188 finished after 499.000000 time steps
# Episode 189 finished after 499.000000 time steps
# Episode 190 finished after 499.000000 time steps
# Episode 191 finished after 499.000000 time steps
# Episode 192 finished after 499.000000 time steps
# Episode 193 finished after 499.000000 time steps
# Episode 194 finished after 499.000000 time steps
# Episode 195 finished after 499.000000 time steps
# Episode 196 finished after 499.000000 time steps
# Episode 197 finished after 499.000000 time steps
# Episode 198 finished after 499.000000 time steps
# Episode 199 finished after 499.000000 time steps
# Episode 200 finished after 499.000000 time steps
# Episode 201 finished after 499.000000 time steps
# Episode 202 finished after 499.000000 time steps
# Episode 203 finished after 499.000000 time steps
# Episode 204 finished after 499.000000 time steps
# Episode 205 finished after 499.000000 time steps
# Episode 206 finished after 499.000000 time steps
# Episode 207 finished after 499.000000 time steps
# Episode 208 finished after 499.000000 time steps
# Episode 209 finished after 499.000000 time steps
# Episode 210 finished after 499.000000 time steps
# Episode 211 finished after 499.000000 time steps
# Episode 212 finished after 499.000000 time steps
# Episode 213 finished after 499.000000 time steps
# Episode 214 finished after 499.000000 time steps
# Episode 215 finished after 499.000000 time steps
# Episode 216 finished after 499.000000 time steps
# Episode 217 finished after 499.000000 time steps
# Episode 218 finished after 499.000000 time steps
# Episode 219 finished after 499.000000 time steps
# Episode 220 finished after 499.000000 time steps
# Episode 221 finished after 499.000000 time steps
# Episode 222 finished after 499.000000 time steps
# Episode 223 finished after 499.000000 time steps
# Episode 224 finished after 499.000000 time steps
# Episode 225 finished after 499.000000 time steps
# Episode 226 finished after 499.000000 time steps
# Episode 227 finished after 499.000000 time steps
# Episode 228 finished after 499.000000 time steps
# Episode 229 finished after 499.000000 time steps
# Episode 230 finished after 499.000000 time steps
# Episode 231 finished after 499.000000 time steps
# Episode 232 finished after 499.000000 time steps
# Episode 233 finished after 499.000000 time steps
# Episode 234 finished after 499.000000 time steps
# Episode 235 finished after 499.000000 time steps
# Episode 236 finished after 499.000000 time steps
# Episode 237 finished after 499.000000 time steps
# Episode 238 finished after 499.000000 time steps
# Episode 239 finished after 499.000000 time steps
# Episode 240 finished after 499.000000 time steps
# Episode 241 finished after 499.000000 time steps
# Episode 242 finished after 499.000000 time steps
# Episode 243 finished after 499.000000 time steps
# Episode 244 finished after 499.000000 time steps
# Episode 245 finished after 499.000000 time steps
# Episode 246 finished after 499.000000 time steps
# Episode 247 finished after 499.000000 time steps
# Episode 248 finished after 499.000000 time steps
# Episode 249 finished after 499.000000 time steps
# Episode 250 finished after 499.000000 time steps
# Episode 251 finished after 499.000000 time steps
# Episode 252 finished after 499.000000 time steps
# Episode 253 finished after 499.000000 time steps
# Episode 254 finished after 499.000000 time steps
# Episode 255 finished after 499.000000 time steps
# Episode 256 finished after 499.000000 time steps
# Episode 257 finished after 499.000000 time steps
# Episode 258 finished after 499.000000 time steps
# Episode 259 finished after 499.000000 time steps
# Episode 260 finished after 499.000000 time steps
# Episode 261 finished after 499.000000 time steps
# Episode 262 finished after 499.000000 time steps
# Episode 263 finished after 499.000000 time steps
# Episode 264 finished after 499.000000 time steps
# Episode 265 finished after 499.000000 time steps
# Episode 266 finished after 499.000000 time steps
# Episode 267 finished after 499.000000 time steps
# Episode 268 finished after 499.000000 time steps
# Episode 269 finished after 499.000000 time steps
# Episode 270 finished after 499.000000 time steps
# Episode 271 finished after 499.000000 time steps
# Episode 272 finished after 499.000000 time steps
# Episode 273 finished after 499.000000 time steps
# Episode 274 finished after 499.000000 time steps
# Episode 275 finished after 499.000000 time steps
# Episode 276 finished after 499.000000 time steps
# Episode 277 finished after 499.000000 time steps
# Episode 278 finished after 499.000000 time steps
# Episode 279 finished after 499.000000 time steps
# Episode 280 finished after 499.000000 time steps
# Episode 281 finished after 499.000000 time steps
# Episode 282 finished after 499.000000 time steps
# Episode 283 finished after 499.000000 time steps
# Episode 284 finished after 499.000000 time steps
# Episode 285 finished after 499.000000 time steps
# Episode 286 finished after 499.000000 time steps
# Episode 287 finished after 499.000000 time steps
# Episode 288 finished after 499.000000 time steps
# Episode 289 finished after 499.000000 time steps
# Episode 290 finished after 499.000000 time steps
# Episode 291 finished after 499.000000 time steps
# Episode 292 finished after 499.000000 time steps
# Episode 293 finished after 499.000000 time steps
# Episode 294 finished after 499.000000 time steps
# Episode 295 finished after 499.000000 time steps
# Episode 296 finished after 499.000000 time steps
# Episode 297 finished after 499.000000 time steps
# Episode 298 finished after 499.000000 time steps
# Episode 299 finished after 499.000000 time steps
# Episode 300 finished after 499.000000 time steps
# Episode 301 finished after 499.000000 time steps
# Episode 302 finished after 499.000000 time steps

# %%
    visualize()
